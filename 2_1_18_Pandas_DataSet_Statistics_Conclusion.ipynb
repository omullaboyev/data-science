# %% [markdown]
# <a href="https://colab.research.google.com/github/omullaboyev/data-science/blob/main/2_1_18_Pandas_DataSet_Statistics_Conclusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science va Sun'iy Intellekt Praktikum

# %% [markdown]
# Ma'lumotlar Tahlili. Pandas kutubxonasi

# %% [markdown]
# 2.1 Pandas kutubxonasi bilan ishlash.

# %% [markdown]
# 2.1.18 DataSet statistikasi. Umumlashtiruvchi ma'lumotlar.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head() # eng birinchi 5 ta qator
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1         1.8
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4         2.1
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0         5.5
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4         4.0
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1         4.0

# %%
df.shape # df ning hajmi
# Out:
# (13119, 9)

# %%
df.tail() # eng oxirgi 5 ta qator
# Out:
#             model  year  price transmission  ...  fuelType  tax   mpg  engineSize
# 13114     C Class  2020  35999    Automatic  ...    Diesel  145  55.4         2.0
# 13115     B Class  2020  24699    Automatic  ...    Diesel  145  55.4         2.0
# 13116   GLC Class  2019  30999    Automatic  ...    Diesel  145  41.5         2.1
# 13117   CLS Class  2019  37990    Automatic  ...    Diesel  145  45.6         2.0
# 13118     S Class  2019  54999    Automatic  ...    Diesel  145  52.3         2.9
#
# [5 rows x 9 columns]

# %%
df.sample(10) # 10 ta tasodifiy qator
# Out:
#             model  year  price transmission  ...  fuelType  tax   mpg  engineSize
# 12311     A Class  2018  15000       Manual  ...    Petrol  145  50.4         1.6
# 10825     A Class  2019  19200    Automatic  ...    Diesel  145  65.7         1.5
# 1480      E Class  2017  25995    Automatic  ...    Diesel  145  70.6         2.0
# 3853     SL CLASS  2019  51096    Semi-Auto  ...    Petrol  145  36.7         3.0
# 3669      A Class  2019  22799       Manual  ...    Petrol  145  47.1         1.3
# 11852   GLA Class  2016  18990    Semi-Auto  ...    Diesel  125  56.5         2.1
# 7875      V Class  2019  47995    Automatic  ...    Diesel  145  36.7         2.0
# 10549    CL Class  2015  14906       Manual  ...    Petrol  125  51.4         1.6
# 6328    GLC Class  2019  32890    Semi-Auto  ...    Diesel  145  42.2         2.1
# 10889     C Class  2016  17900    Automatic  ...    Petrol  145  49.6         2.0
#
# [10 rows x 9 columns]

# %% [markdown]
# #`info` - DataFrame haqida umumiy ma'lumotlar

# %%
df.info() # df haqida umumiy ma'lumotlar
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %% [markdown]
# #`describe` - tavsiflash.

# %%
df.describe() # df ni tavsiflash
# Out:
#                year          price  ...           mpg    engineSize
# count  13119.000000   13119.000000  ...  13119.000000  13119.000000
# mean    2017.296288   24698.596920  ...     55.155843      2.071530
# std        2.224709   11842.675542  ...     15.220082      0.572426
# min     1970.000000     650.000000  ...      1.100000      0.000000
# 25%     2016.000000   17450.000000  ...     45.600000      1.800000
# 50%     2018.000000   22480.000000  ...     56.500000      2.000000
# 75%     2019.000000   28980.000000  ...     64.200000      2.100000
# max     2020.000000  159999.000000  ...    217.300000      6.200000
#
# [8 rows x 6 columns]

# %% [markdown]
# - count - soni
# - mean - o'rtacha qiymati
# - std - standart deviation, standart og'ish
# - min - eng kichik qiymat
# - 25/50/75% - qiymatlarning 25/50/75% shu oraliqda
# - max - eng katta qiymat

# %%
df["price"].plot.hist(bins = 30) # narhi bo'yicha

# %%
df["year"].plot.hist(bins = 30) # yili bo'yicha
